# %%
"""Глава 2.

Условный оператор.
"""

# %%
# 1.  

print("Как Вас зовут?")
print(f"Здравствуйте, {input()}!")
print("Как дела?")
if input() == "хорошо":
    print("Я за вас рада!")
else:
    print("Всё наладится!")

# %%
# 2.  

v_petya, v_vasya = int(input()), int(input())
if v_petya > v_vasya:
    print("Петя")
else:
    print("Вася")

# %%
# 3.  

v_petya, v_vasya, v_tolya = int(input()), int(input()), int(input())
if v_petya > v_vasya and v_petya > v_tolya:
    print("Петя")
elif v_vasya > v_petya and v_vasya > v_tolya:
    print("Вася")
else:
    print("Толя")

# %%
# 4.  

v_petya, v_vasya, v_tolya = int(input()), int(input()), int(input())
places = {"Петя": v_petya, "Вася": v_vasya, "Толя": v_tolya}
sorted_places = dict(sorted(places.items(), key=lambda item: item[1], reverse=True))
for i, (key, value) in enumerate(sorted_places.items(), start=1):
    print(f"{i}. {key}")

# %%
# 5.  

N, M = int(input()), int(input())
apples_petya = 7 - 3 + 2 + N
apples_vasya = 6 + 3 + 5 - 2 + M
if apples_petya > apples_vasya:
    print("Петя")
else:
    print("Вася")

# %%
# 6.  

year = int(input())
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("YES")
else:
    print("NO")

# %%
# 7.  

n = input()
if n == n[::-1]:
    print("YES")
else:
    print("NO")

# %%
# 8.  

area = input()
if "зайка" in area:
    print("YES")
else:
    print("NO")

# %%
# 9.  

name1, name2, name3 = input(), input(), input()
if name1 <= name2 and name1 <= name3:
    print(name1)
elif name2 <= name1 and name2 <= name3:
    print(name2)
else:
    print(name3)

# %%
# 10.  

n = int(input())
a = n // 100
b = n // 10 % 10
c = n % 10
junior = b + c
old = a + b
if old > junior:
    print(old, junior, sep="")
else:
    print(junior, old, sep="")

# %%
# 11.  

n = int(input())
a = n // 100
b = n // 10 % 10
c = n % 10
max_digit = max(a, b, c)
min_digit = min(a, b, c)
mid_digit = a + b + c - max_digit - min_digit
if max_digit + min_digit == 2 * mid_digit:
    print("YES")
else:
    print("NO")

# %%
# 12.  

a, b, c = int(input()), int(input()), int(input())
if a + b > c and a + c > b and c + b > a:
    print("YES")
else:
    print("NO")

# %%
# 13.  

elfs, dwarfs, men = input().strip(), input().strip(), input().strip()
if elfs[0] == dwarfs[0] == men[0]:
    print(elfs[0])
elif elfs[1] == dwarfs[1] == men[1]:
    print(elfs[1])

# %%
# 14.  

numbers = input().strip()
combinations = []
for i in range(len(numbers)):
    for j in range(len(numbers)):
        if i != j and int(numbers[i] + numbers[j]) > 9:
            combinations.append(int(numbers[i] + numbers[j]))
print(min(combinations), max(combinations))

# %%
# 15.

n, m = input().strip(), input().strip()
all_digits = list(map(int, n + m))
max_digit = max(all_digits)
min_digit = min(all_digits)
remaining_digits = all_digits.copy()
remaining_digits.remove(max_digit)
remaining_digits.remove(min_digit)
sum_digit = sum(remaining_digits) % 10
print(f"{max_digit}{sum_digit}{min_digit}")

# %%
# 16.

v_petya, v_vasya, v_tolya = int(input()), int(input()), int(input())

first = second = third = ""
if v_petya > v_vasya > v_tolya:
    first = "Петя"
    second = "Вася"
    third = "Толя"
elif v_petya > v_tolya > v_vasya:
    first = "Петя"
    second = "Толя"
    third = "Вася"
elif v_vasya > v_tolya > v_petya:
    first = "Вася"
    second = "Толя"
    third = "Петя"
elif v_vasya > v_petya > v_tolya:
    first = "Вася"
    second = "Петя"
    third = "Толя"
elif v_tolya > v_petya > v_vasya:
    first = "Толя"
    second = "Петя"
    third = "Вася"
elif v_tolya > v_vasya > v_petya:
    first = "Толя"
    second = "Вася"
    third = "Петя"

print(f"{"":^8}{first:^8}")
print(f"{second:^8}")
print(f"{"":^16}{third:^8}")
print(f"{"II":^8}{"I":^8}{"III":^8}")

# %%
# 17.  

a, b, c = float(input()), float(input()), float(input())

discriminant = b**2 - 4 * a * c
if a == b == c == 0:
    print("Infinite solutions")
elif a == b == 0 or discriminant < 0:
    print("No solution")
elif a == 0 and b != 0 and c != 0:
    print(f"{-(c / b):.2}")
elif a == c == 0:
    print(0)
elif discriminant == 0:
    print(f"{(-b / (2 * a)):.2f}")
else:
    x1 = (-b + discriminant**0.5) / (2 * a)
    x2 = (-b - discriminant**0.5) / (2 * a)
    print(f"{min(x1, x2):.2f} {max(x1, x2):.2f}")

# %%
# 18.  

a, b, c = int(input()), int(input()), int(input())

if a > b and a > c:
    a, b, longest = b, c, a
elif b > a and b > c:
    a, b, longest = a, c, b
else:
    a, b, longest = a, b, c

if a**2 + b**2 == longest**2:
    print("100%")
elif a**2 + b**2 < longest**2:
    print("велика")
else:
    print("крайне мала")

# %%
# 19.  

x, y = float(input()), float(input())

if x**2 + y**2 > 100:
    print("Вы вышли в море и рискуете быть съеденным акулой!")
elif (4 * y > (x + 1)**2 - 36 and
     y < 5 and
     y**2 < 25 - x**2 and
     3 * y < 5 * x + 35):
    print("Опасность! Покиньте зону как можно скорее!")
else:
    print("Зона безопасна. Продолжайте работу.")

# %%
# 20.  

line_1, line_2, line_3 = input(), input(), input()

ans = ""
for line in (line_1, line_2, line_3):
    if "зайка" in line and (ans == "" or line < ans):
        ans = line
print(ans, len(ans))
